# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 
import json
from numpy import array
pd.options.display.max_columns = None
pd.options.display.max_rows = None

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure as fig

# %%
datapath="hdfs://cdh1:8020/user/hbase/pro_dfjk4new/battery_data/2019-10-01/"
data=spark.read.json(datapath)
type(data)
data.first()
# Out:
# pyspark.sql.dataframe.DataFrame
# ...

# %%
# data.registerTempTable('cdata1')
# # 查询分组数量
# spark.sql("select count(distinct) from (select vin from cdata1 group by vin)").show()
# spark.sql("select vin from cdata1 group by vin").show()

# %%
# 统计分组后的每组数据条数
# data.groupBy('vin').count().show()
# 统计数据行数
# data.count()

# %%
data1=data.select("vin","obd_time","resd_subsystem_temperature_list")
# data2=data1.toDF()
# data2=spark.createDataFrame(data1)
data1.show(truncate=False)
# Out:
# +-----------------+-------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |vin              |obd_time           |resd_subsystem_temperature_list                                                                                                                                                                          |
# +-----------------+-------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |LEWWCA321JN400711|2019-09-30 23:38:13|[{'subsystem_probe_temperature_list': [37, 37, 37, 37, 36, 38, 38, 37, 38, 37, 38, 37, 37, 39, 38, 39, 38, 39, 38, 37, 36, 37, 38, 38], 'subsystem_temperature_probes_count': 24, 'subsystem_number': 1}]|
# ...

# %%
data1=data.select('resd_subsystem_temperature_list').rdd.map(lambda x:eval(x[0])['subsystem_probe_temperature_list'])
# data1.head(1)
data2=spark.createDataFrame(data1)
data2.show()
# data1.select('resd_subsystem_temperature_list')=data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-59a4ebead9bc> in <module>()
# ----> 1 data1=data.select('resd_subsystem_temperature_list').rdd.map(lambda x:eval(x[0])['subsystem_probe_temperature_list'])
#       2 # data1.head(1)
#       3 data2=spark.createDataFrame(data1)
#       4 data2.show()
#       5 # data1.select('resd_subsystem_temperature_list')=data2
#
# NameError: name 'data' is not defined
