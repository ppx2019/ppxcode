# %%
import json
import datetime
import pandas as pd
from numpy import array
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure as fig

from matplotlib.font_manager import FontProperties
from pyspark.sql import *
from pyspark.mllib.linalg import *
from pyspark.sql.functions import *
# 读取本机hdfs文件
# data=spark.read.parquet("hdfs://192.168.3.114:9000/hdfsfile/2018-05-25/")

data=spark.read.parquet("file:///Users/ppx/Desktop/2018-05-25-1")
data.first()
# Out:
# Row(battery_cell_consistency_low_alert='False', battery_cell_count=[144], battery_cell_voltage_highest_value='4.16', battery_cell_voltage_list=[3.99, 4.15, 4.11, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.13, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.07, 4.12, 4.15, 4.05, 4.15, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.11, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 3.99, 4.15, 4.11, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.16, 4.04, 4.15, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.12, 4.06, 4.12, 4.12, 4.12, 4.12, 4.12, 4.
# ...

# %%
# 总电压与单体电池最高电压关系
data1=data.select("voltage","battery_cell_voltage_highest_value")

# 将df列转换为指定类型
data1=data1.select(data1.voltage.astype("float"),data1.battery_cell_voltage_highest_value.astype("float"))
data1.show(1)

# 计算两列的相关系数
data1.corr("voltage","battery_cell_voltage_highest_value")

#
data1.voltage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-781dee075502> in <module>()
#       1 # 总电压与单体电池最高电压关系
# ----> 2 data1=data.select("voltage","battery_cell_voltage_highest_value")
#       3
#       4 # 将df列转换为指定类型
#       5 data1=data1.select(data1.voltage.astype("float"),data1.battery_cell_voltage_highest_value.astype("float"))
#
# NameError: name 'data' is not defined
