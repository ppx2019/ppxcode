# %%
import pandas as pd
from numpy import array
import numpy as np

from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import matplotlib.figure as fig

data=spark.read.parquet("file:///Users/ppx/Desktop/2018-05-25 2")
data.show()
type(data)
# Out:
# +----------------------------------+------------------+----------------------------------+-------------------------+---------------------------------+-------------------+--------------------+------------------------------+--------------------+---------+---------+----------+-------------+-------+------------+------------------+-----------------------+------------+----------------------------------------+---------------------------------------+---------------------------------------+------------------+-------------------+------------+-------------------+----------+----------------+---------------------+-----------------+---------+--------+------------------------------+----------------------------------+-------------------------+---------------------------------+--------------------------------------+-------+------------------------------+----------------------------------+-------------------------+---------------------------------+--------------------------------------+---------------
# ...

# %%
from sklearn.cluster import KMeans
# data21=spark.read.text(\"file:///Users/ppx/Desktop/var.txt\")
# data22=np.array(data21)

# 数据标准化
# list21=1.0*(list1-list1.mean())/list1.std()
list2=np.array(list1).reshape(-1,1).round(4)
list2
# 构造聚类器
kmeans=KMeans(n_clusters=2,max_iter=1000,n_jobs=4)
kmeans.fit(list2)

# 获取聚类标签
kmeans.labels_

# 获取聚类中心
kmeans.cluster_centers_

# 获取聚类准则的总和
kmeans.inertia_
# Out:
# array([[0.0004],
#        [0.0004],
#        [0.0004],
#        ...,
#        [0.0063],
#        [0.0063],
#        [0.0063]])
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#        n_clusters=2, n_init=10, n_jobs=4, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)
# array([[0.02136952],
#        [3.02866034]])
# 280.0556461206876

# %%
plt.scatter(list2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-62c8df4f7e74> in <module>()
# ----> 1 plt.scatter(list2)
#
# NameError: name 'list2' is not defined

# %%
# 元祖
rdd_data=data.select('battery_cell_voltage_list').rdd.map(lambda x:((xi-(sum(x[0])/len(x[0]))**2 for xi in x[0])/len(x[0]))
# rdd_data\n",
type(rdd_data)
data22=spark.createDataFrame(rdd_data)
type(data22)
# Out:
#   File "<ipython-input-8-39cc7e25433e>", line 4
#     type(rdd_data)
#        ^
# SyntaxError: invalid syntax

# %%
# data.select('battery_cell_voltage_list').collect()
data1=data.select('obd_time','battery_cell_voltage_list').rdd.map(lambda x:x[1]).collect()
type(data1)
# data1


# 自定义方差公式,列表格式计算,RDD和DF没有迭代
list1=[]
for n in data1:
    a=sum(n)/len(n)
    list1.append(sum((xi-a)**2 for xi in n)/len(n))
print(list1)
# type(list1)
# Out:
# list
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

X,y=make_blobs(n_samples=)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d426234c3e48> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 from sklearn.datasets import make_blobs
# ----> 3 X,y=mak
#
# NameError: name 'mak' is not defined

# %%
X,y=make_blobs(n_samples=10,n_features=2,centers=2,random_state=1)

# %%
X
# Out:
# array([[-10.17014071,  -4.83120697],
#        [-11.09833168,  -2.80862484],
#        [ -9.95549876,  -3.37053333],
#        [ -8.86394306,  -5.05323981],
#        [  0.08525186,   3.64528297],
#        [ -0.79415228,   2.10495117],
#        [ -1.34052081,   4.15711949],
#        [-10.32012971,  -4.3374029 ],
#        [ -2.18773166,   3.33352125],
#        [ -0.19745197,   2.34634916]])

# %%
y
# Out:
# array([1, 1, 1, 1, 0, 0, 0, 1, 0, 0])

# %%
#
fig,ax1=plt.subplots(1)
ax1.scatter(X[:,0],X[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans

cluster=KMeans(n_clusters=3,random_state=0).fit(X)
cluster.labels_
# Out:
# array([0, 2, 2, 0, 1, 1, 1, 0, 1, 1], dtype=int32)
