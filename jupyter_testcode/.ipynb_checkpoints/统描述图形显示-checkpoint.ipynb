# %%
import pandas as pd
from numpy import array
import numpy as np
from scipy.stats import mstats

import matplotlib.pyplot as plt
import matplotlib.figure as fig

# %%
data1=np.array([1,2,2,6,8,7,6,4,2])
mean=data1.mean()
mean
std=data1.std()
std

# rd=np.random.randn(50,10)
qu=mstats.mquantiles(rd,axis=0)
labels=['25%','50%','75%']
for i,q in enumerate(qu):
    plt.plot(q,label=labels[i])
plt.legend()
# Out:
# 4.222222222222222
# 2.4393887111222385

# %%
# 绘制直方图
plt.hist(data1)
plt.show()
# Out:
# (array([1., 3., 0., 0., 1., 0., 0., 2., 1., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <a list of 10 Patch objects>)
