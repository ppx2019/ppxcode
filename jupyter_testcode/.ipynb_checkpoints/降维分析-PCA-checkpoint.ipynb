# %%
# Out:
# 中心化后样本: [[-1.  0.]
#  [-1.  2.]]
# 样本协方差： [[0.5 1.5]
#  [1.5 4.5]]
# 特征值：[0. 5.]
# 特征向量：[[-0.9486833  -0.31622777]
#  [ 0.31622777 -0.9486833 ]]

# %%
from numpy import array
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import datetime

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

# 使用spark读取数据
data=sc.textFile("hdfs://cdh1:8020/user/hbase/2019-10-01/vin=LDPBAAKB9JN401989/")
data.take(1)
# Out:
# ['{"obd_time":"2019-10-01 06:36:32","charge_status":"\\\\xE6\\\\x9C\\\\xAA\\\\xE5\\\\x85\\\\x85\\\\xE7\\\\x94\\\\xB5","voltage":"382.0","current":"3.0","battery_cell_voltage_highest_value":"3.983","battery_cell_voltage_lowest_value":"3.971","maximum_temperature_value":"27","minimum_temperature_value":"25","has_alert":"false","highest_alert_level":"\\\\xE6\\\\x97\\\\xA0\\\\xE6\\\\x95\\\\x85\\\\xE9\\\\x9A\\\\x9C","temperature_difference_alert":"False","battery_high_temperature_alert":"False","energy_storage_device_high_voltage_alert":"False","energy_storage_device_low_voltage_alert":"False","soc_low_alert":"False","single_battery_high_voltage_alert":"False","single_battery_low_voltage_alert":"False","soc_too_high_alert":"False","soc_jumping_alert":"False","rechargeable_energy_storage_system_mismatch_alert":"False","battery_cell_consistency_low_alert":"False","insulation_alert":"False","dc_dc_temperature_alert":"False","braking_system_alert":"False","dc_dc_status_alert":"False","motor_controller_temperature_alert":"False","hvil_alert":"False","motor_temperature_alert":"False","energy_storage_device_over_charge_alert":"False","battery_faults_count":"0","battery_fault_codes":"[]","resd_subsystem_count":"1","resd_subsystem_voltage_list":"[{\'subsystem_current\': 2.9, \'subsystem_voltage\': 382.0, \'battery_cell_count\': 96, \'battery_cell_voltage_list\': [3.981, 3.979, 3.979, 3.979, 3.98, 3.979, 3.98, 3.979, 3.979, 3.98, 3.98, 3.98, 3.979, 3.98, 3.982, 3.979, 3.98, 3.98, 3.971, 3.979, 3.98, 3.981, 3.98, 3.979, 3.98, 3.981, 3.979, 3.981, 3.98, 3.98, 3.981, 3.981, 3.981, 3.98, 3.974, 3.981, 3.979, 3.979, 3.98, 3.98, 3.98, 3.982, 3.983, 3.981, 3.98, 3.981, 3.98, 3.981, 3.981, 3.98, 3.98, 3.979, 3.98, 3.98, 3.979, 3.98, 3.981, 3.981, 3.979, 3.979, 3.98, 3.98, 3.98, 3.981, 3.979, 3.98, 3.98, 3.982, 3.978, 3.977, 3.978, 3.981, 3.98, 3.978, 3.979, 3.98, 3.979, 3.979, 3.98, 3.98, 3.981, 3.98, 3.979, 3.98, 3.978, 3.98, 3.979, 3.98, 3.979, 3.981, 3.979, 3.98, 3.98, 3.979, 3.978, 3.979], \'subsystem_number\': 1}]","resd_subsystem_temperature_list":"[{\'subsystem_probe_temperature_list\': [26, 26, 26, 26, 26, 27, 27, 26, 26, 27, 27, 27, 26, 27, 26, 26, 25, 26, 26, 26, 26, 26, 27, 27], \'subsystem_temperature_probes_count\': 24, \'subsystem_number\': 1}]"}']

# %%
data_js=data.map(lambda line:json.loads(line))
data_js.first()
# Out:
# {'battery_cell_consistency_low_alert': 'False',
#  'battery_cell_voltage_highest_value': '3.983',
#  'battery_cell_voltage_lowest_value': '3.971',
#  'battery_fault_codes': '[]',
#  'battery_faults_count': '0',
#  'battery_high_temperature_alert': 'False',
#  'braking_system_alert': 'False',
#  'charge_status': '\\xE6\\x9C\\xAA\\xE5\\x85\\x85\\xE7\\x94\\xB5',
#  'current': '3.0',
#  'dc_dc_status_alert': 'False',
#  'dc_dc_temperature_alert': 'False',
#  'energy_storage_device_high_voltage_alert': 'False',
#  'energy_storage_device_low_voltage_alert': 'False',
#  'energy_storage_device_over_charge_alert': 'False',
#  'has_alert': 'false',
#  'highest_alert_level': '\\xE6\\x97\\xA0\\xE6\\x95\\x85\\xE9\\x9A\\x9C',
#  'hvil_alert': 'False',
#  'insulation_alert': 'False',
#  'maximum_temperature_value': '27',
#  'minimum_temperature_value': '25',
#  'motor_controller_temperature_alert': 'False',
#  'motor_temperature_alert': 'False',
#  'obd_time': '2019-10-01 06:36:32',
#  'rechargeable_energy_storage_system_mismatch_alert': 'False',
#  'resd_subsystem_count': '1',
#  'resd_subsystem_temperature_list': "[{'subsystem_probe_temperature_list': [26, 26, 26, 26, 26, 27, 27, 26, 26, 27, 27, 27, 26, 27, 26, 26, 25, 26, 26, 26, 26, 26, 27, 27], 'subsystem_temperature_probes_count': 24, 'subsystem_number': 1}]",
#  'resd_subsystem_voltage_list': "[{'subsystem_current': 2.9, 'subsystem_voltage': 382.0, 'battery_cell_count': 96, 'battery_cell_voltage_list': [3.981, 3.979, 3.979, 3.979, 3.98, 3.979, 3.98, 3.979, 3.979, 3.98, 3.98, 3.98, 3.979, 3.98, 3.982, 3.979, 3.98, 3.98, 3.971, 3.979, 3.98, 3.981, 3.98, 3.979, 3.98, 3.981, 3.979, 3.981, 3.98, 3.98, 3.981, 3.981, 3.981, 3.98, 3.974, 3.981, 3.979, 3.979, 3.98, 3.98, 3.98, 3.982, 3.983, 3.981, 3.98, 3.981, 3.98, 3.981, 3.981, 3.98, 3.98, 3.979, 3.98, 3.98, 3.979, 3.98, 3.981, 3.981, 3.979, 3.979, 3.98, 3.98, 3.98, 3.981, 3.979, 3.98, 3.98, 3.982, 3.978, 3.977, 3.978, 3.981, 3.98, 3.978, 3.979, 3.98, 3.979, 3.979, 3.98, 3.98, 3.981, 3.98, 3.979, 3.98, 3.978, 3.98, 3.979, 3.98, 3.979, 3.981, 3.979, 3.98, 3.98, 3.979, 3.978, 3.979], 'subsystem_number': 1}]",
#  'single_battery_high_voltage_alert': 'False',
#  'single_battery_low_voltage_alert': 'False',
#  'soc_jumping_alert': 'False',
#  'soc_low_alert': 'False',
#  'soc_too_high_alert': 'False',
#  'temperature_difference_alert': 'False',
#  'voltage': '382.0'}
