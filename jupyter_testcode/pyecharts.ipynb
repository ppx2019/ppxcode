# %%
# 使jupyter能够交互式显示图像
# %matplotlib notebook

import json
import datetime
import pandas as pd
from numpy import array
import numpy as np
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
import matplotlib.figure as fig
from pyspark.sql import *
import matplotlib.font_manager as fm
my_font=fm.FontProperties(fname="/Users/ppx/Desktop/中文字体/simsun.ttf")


from pyecharts import options as opts
from pyecharts.charts import Kline
from pyecharts.charts import Bar

# %%
# 加载 LEWTEB144HE103899 数据
data=spark.read.json("hdfs://cdh1:8020/user/hbase/pro_dfjk4new/fault_data/2019-08-23/")
# data.collect()
# 电压趋势图
data1=data.toPandas()
data1
# Out:
#    battery_cell_consistency_low_alert battery_cell_voltage_highest_value  \
# 0                               False                               3.84
# 1                               False                               3.84
# 2                               False                               3.84
# 3                               False                               3.84
# 4                               False                               3.86
# ..                                ...                                ...
# 76                              False                                4.1
# 77                              False                               4.12
# 78                              False                                4.1
# 79                              False                               4.08
# 80                              False                               4.08
#
#    battery_cell_voltage_lowest_value battery_fault_codes battery_faults_count  \
# ...

# %%
c=(
    # 散点图
#     Scatter(init_opts=opts.InitOpts(width="1000px",height="500px",bg_color="",chart_id="",renderer="svg",theme="while"))
    Line(init_opts=opts.InitOpts(width="1000px",height="500px",bg_color="",chart_id="",renderer="svg",theme="while"))
    # 添加x轴数据
    .add_xaxis(xaxis_data=data1.obd_time)
    # 添加y轴数据
    # 最高温度
    .add_yaxis(series_name="最高温度",
               y_axis=data1.maximum_temperature_value.values.tolist(),
               markpoint_opts=opts.MarkPointOpts(
                   symbol="",
                   symbol_size="",
                   label_opts="",
                   data=[
                       opts.MarkPointItem(name="最大值",type_="max",x="",y="",value_index="",value_dim="",
                                          coord="",symbol="",symbol_size=""),
                       opts.MarkPointItem(name="最小值",type_="min",x="",y="",value_index="",value_dim="",
                                          coord="",symbol="",symbol_size="")]
                   
               ),
               
               markline_opts=opts.MarkLineOpts(
                   is_silent="",
                   symbol="",
                   symbol_size="",
                   precision="",
                   label_opts="",
                   linestyle_opts="",
                   data=[
                       opts.MarkLineItem(name="平均值",type_="average",x="",y="",value_index="",
                                         value_dim="",coord="",symbol="",symbol_size="")]   
               ),                
    )
    
    # 最低温度
    .add_yaxis(series_name="最低温度",
               y_axis=data1.minimum_temperature_value.values.tolist(),
               markpoint_opts=opts.MarkPointOpts(
                   symbol="",
                   symbol_size="",
                   label_opts="",
                   data=[
                       opts.MarkPointItem(name="最大值",type_="max",x="",y="",value_index="",value_dim="",
                                          coord="",symbol="",symbol_size=""),
                       opts.MarkPointItem(name="最小值",type_="min",x="",y="",value_index="",value_dim="",
                                          coord="",symbol="",symbol_size="")]
                   
               ),
               
               markline_opts=opts.MarkLineOpts(
                   is_silent="",
                   symbol="",
                   symbol_size="",
                   precision="",
                   label_opts="",
                   linestyle_opts="",
                   data=[
                       opts.MarkLineItem(name="平均值",type_="average",x="",y="",value_index="",
                                         value_dim="",coord="",symbol="",symbol_size="")]   
               ),                
    )
    
    
    # 设置全局配置
    .set_global_opts(
        # 标题配置
        title_opts=opts.TitleOpts(title="电池温度变化",title_link="",title_target="",subtitle="最高最低温度",subtitle_link="",
                                  subtitle_target="",pos_left="left",pos_right="",pos_top="",pos_bottom="",padding="6",
                                  item_gap="",title_textstyle_opts="",subtitle_textstyle_opts=""),
        # 缩放区域配置
        datazoom_opts=[opts.DataZoomOpts(is_show="True",type_="slider",is_realtime="True",range_start="0",range_end="100",
                                         start_value="",end_value="",orient="horizontal",xaxis_index="",yaxis_index="",
                                         is_zoom_lock="",pos_left="",pos_right="",pos_top="",pos_bottom=""),
                       opts.DataZoomOpts(is_show="True",type_="inside",is_realtime="True",range_start="0",range_end="100",
                                         start_value="",end_value="",orient="horizontal",xaxis_index="",yaxis_index="",
                                         is_zoom_lock="",pos_left="",pos_right="",pos_top="",pos_bottom="")],
        # 图例配置
        legend_opts=opts.LegendOpts(is_show="True",type_="scroll",selected_mode="True",pos_left="",pos_right="",
                                    pos_top="",pos_bottom="",orient="horizontal",align="left",padding="",item_gap="",
                                    item_width="",item_height="", inactive_color="",legend_icon="",
                                    # 文字样式配置
#                                     textstyle_opts=opts.TextStyleOpts(
#                                         color="yellow",font_style="30",font_weight="bold",font_family="",font_size="",align="",
#                                         vertical_align="",line_height="",background_color="",border_color="",
#                                         border_width="",border_radius="",padding="",shadow_color="",shadow_blur="",
#                                         width="",height="",rich=""),
                                   ),
        # 视觉映射配置
#         visualmap_opts=opts.VisualMapOpts(is_show="False",type_="color",min_="",max_="",range_text="high",
#                                           range_color="",range_size="",range_opacity="",orient="vertical",pos_left="",
#                                           pos_right="",pos_top="",pos_bottom="",split_number="",series_index="",dimension="",
#                                           is_calculable="",is_piecewise="",is_inverse="",pieces="", out_of_range="",
#                                           item_width="",item_height="",background_color="",border_width="1",
#                                           textstyle_opts=""),
        # 提示框配置
        tooltip_opts=opts.TooltipOpts(is_show="True",trigger="axis",trigger_on="mousemove",axis_pointer_type="cross",
                                      formatter="",background_color="",border_color="#FFCOCB",border_width="",
                                      # 文字样式配置
#                                       textstyle_opts=
#                                           opts.TextStyleOpts(
#                                               color="",font_style="",font_weight="",
#                                               font_family="",font_size="",align="",
#                                               vertical_align="",line_height="",background_color="",border_color="",
#                                               border_width="",border_radius="",padding="",shadow_color="",shadow_blur="",
#                                               width="",height="",rich=""),
                                      ),
        
        # 坐标轴指示器配置
        axispointer_opts=opts.AxisPointerOpts(is_show="",link="",type_="line",label="",linestyle_opts=""),
        
        # x坐标轴配置--全局中只能对单轴x或y
        xaxis_opts=opts.AxisOpts(
            type_="time",name="时间(s)",is_show="",is_scale="",is_inverse="",name_location="end",
            name_gap="",name_rotate="",interval="",grid_index="",position="",offset="",
            split_number="",boundary_gap="",min_="",max_="",max_interval="",min_interval="",
            # 轴线配置
            axisline_opts=opts.AxisLineOpts(
                is_show="",is_on_zero="True",on_zero_axis_index="",symbol="arrow",linestyle_opts=""),
            # 轴标签配置
            axislabel_opts=opts.LabelOpts(
                is_show="",position="",color="",font_size="",font_style="",font_weight="",
                font_family="",rotate="",margin="",interval="",horizontal_align="",vertical_align="",
                formatter="",rich=""),
            # 轴指示器配置
            axispointer_opts=opts.AxisPointerOpts(
                is_show="False",link="",type_="line",label="",linestyle_opts=""),
            # 文字样式配置
            name_textstyle_opts="",
            splitarea_opts="",
            splitline_opts="",
            # 轴刻度配置
            axistick_opts=opts.AxisTickOpts(
                is_show="",is_align_with_label="",is_inside="False",length="",linestyle_opts="")
        ),
        # y坐标轴配置
        yaxis_opts=opts.AxisOpts(
            type_="value",name="温度(℃)",is_show="",is_scale="",is_inverse="",name_location="",
            name_gap="",name_rotate="",interval="",grid_index="0",position="",offset="",
            split_number="",boundary_gap="",min_="",max_="",max_interval="",min_interval="",
            # 轴线配置
            axisline_opts=opts.AxisLineOpts(
                is_show="False",is_on_zero="True",on_zero_axis_index="",symbol="arrow",linestyle_opts=""),
            # 轴标签配置
            axislabel_opts=opts.LabelOpts(is_show="",position="",color="",font_size="",font_style="",font_weight="",
                                  font_family="",rotate="",margin="",interval="",horizontal_align="",vertical_align="",
                                  formatter="",rich=""),
            # 轴指示器配置
            axispointer_opts=opts.AxisPointerOpts(
                is_show="True",link="",type_="line",label="",linestyle_opts=""),
            # 字体样式配置
            name_textstyle_opts="",
            splitarea_opts="",
            splitline_opts="",
            # 轴刻度配置
            axistick_opts=opts.AxisTickOpts(
                is_show="",is_align_with_label="",is_inside="False",length="",linestyle_opts="")
        )
        
        
    )
    
    
    
    # 设置系列配置
    .set_series_opts(
        # 单轴配置
        singleaxis_opts=opts.SingleAxisOpts(name="",max_="",min_="",pos_left="",pos_right="",pos_top="",pos_bottom="",
                                            width="",height="",orient="",type_=""),
        
        # 图元样式配置
        itemstyle_opts=opts.ItemStyleOpts(color="",color0="",border_color="",border_color0="",opacity=""),
        # 标签配置-数值标注
        label_opts=opts.LabelOpts(is_show="",position="",color="",font_size="",font_style="",font_weight="",
                                  font_family="",rotate="",margin="",interval="",horizontal_align="",vertical_align="",
                                  formatter="",rich=""),
        # 线样式配置
        linestyle_opts=opts.LineStyleOpts(is_show="",width="",opacity="",curve="",type_="",color=""),
        # 3D线样式配置
        lines3deffect_opts=opts.Lines3DEffectOpts(is_show="",period="",trail_length="",trail_color="",trail_opacity=""),
        # 分割线配置
        splitline_opts=opts.SplitLineOpts(is_show="",linestyle_opts=""),
        
        # 标记区域数据
#         markarealtem=opts.MarkAreaItem(name="",type_="",value_index="",value_dim="",x="",y="",label_opts="",
#                                        itemstyle_opts=""),
        # 标记区域配置
        markarea_opts=opts.MarkAreaOpts(is_silent="",label_opts="",data=""),
        # 涟漪特效配置
        effect_opts=opts.EffectOpts(is_show="",brush_type="",period="",color="",symbol="",symbol_size="",
                                    trail_length=""),
        # 区域填充样式配置
        areastyle_opts=opts.AreaStyleOpts(opacity="0.1",color="#FFCCFF"),
        # 分割区域配置
        splitarea_opts=opts.SplitAreaOpts(is_show="",areastyle_opts=""),
        
    # 存储图表到指定路径
#     .render("/Users/ppx/Desktop/3.html")
    )
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'while':'https://assets.pyecharts.org/assets/themes/shine'
#         }
#     });
# </script>
#
#         <div id="208e458da97f4650acb54ee131a19424" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'while'], function(echarts) {
#                 var chart_208e458da97f4650acb54ee131a19424 = echarts.init(
#                     document.getElementById('208e458da97f4650acb54ee131a19424'), 'while', {renderer: 'svg'});
#                 var option_208e458da97f4650acb54ee131a19424 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "line",
# ...

# %%
# shan
